# %%
mini=1
maxm=100

import random
ans=random.randint(mini,maxm)
win=True
while win:
    x=int(input())
    if x==ans:
        print("win")
        win=False
    elif x<ans:
        mini=x
        print("請輸入"+str(mini)+"~"+str(maxm)+"之間")
        continue
    elif x>ans:
        maxm=x
        print("請輸入"+str(mini)+"~"+str(maxm)+"之間")
        continue
# Out:
# 20
# 請輸入20~100之間
# 40
# 請輸入40~100之間
# 70
# 請輸入40~70之間
# 50
# 請輸入50~70之間
# 60
# 請輸入60~70之間
# 65
# 請輸入65~70之間
# 68
# 請輸入68~70之間
# 69
# win
